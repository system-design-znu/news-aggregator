# %%
import 
import pySql as psql
import mongodb_fetcher as mf

md = mf.MongoFetcher(27017,"nag","sample_news")
data = md.returnall()  
ps = psql.pySql(data,'postgres','123456','localhost',5432,'postgres')
ps.select_all_news()
# Out:
# [('https://www.irna.ir/news/85029984/۸۳-درصد-گوشت-مصرفی-کشور-در-داخل-تولید-می-شود',
#   '۸۳ درصد گوشت مصرفی کشور در داخل تولید می\u200cشود',
#   'مشهد -ایرنا- معاون وزیر و رییس سازمان دامپزشکی کشور گفت: هم اکنون ۸۳  درصد گوشت مصرفی کشور در داخل تولید می\u200cشود.',
#   'https://img9.irna.ir/d/r1/2019/12/08/4/156812418.jpg',
#   'image/jpeg',
#   'rkhorasan',
#   'Tue, 14 Feb 2023 10:55:40 GMT',
#   'آرزو عرفانی جاودانی'),
#  ('https://www.irna.ir/news/85030192/خودشیفته-جایزه-بهترین-فیلم-در-شهر-داکا-را-کسب-کرد',
#   'خودشیفته جایزه بهترین فیلم در شهر داکا را کسب کرد',
#   'کرج - ایرنا - فیلم کوتاه «خودشیفته» به نویسندگی و کارگردانی اسماعیل خاکباز از استان البرز  موفق به دریافت جایزه بهترین فیلم در شهر داکا  کشور بنگلادش شد.',
#   'https://img9.irna.ir/d/r2/2023/02/14/4/170184712.jpg',
#   'image/jpeg',
#   'alborz',
#   'Tue, 14 Feb 2023 10:55:40 GMT',
#   'خبرگزاری جمهوری اسلامی |صفحه اصلی | IRNA News Agency'),
# ...
